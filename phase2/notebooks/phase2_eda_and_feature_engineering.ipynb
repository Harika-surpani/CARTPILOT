# %% [markdown]
# # Phase 2: Cart Abandonment Dataset Analysis & Feature Engineering
#
# **Project:** CartPilot - AI-Powered Cart Rescue Platform
# **Objective:** Transform raw clickstream events into a clean, session-aggregated ML-ready dataset for real-time cart abandonment prediction.
# **Dataset:** E-commerce Clickstream and Transaction Dataset (`ecommerce_clickstream_transactions.csv`)
#
# ---

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Add src directory to path
sys.path.append(os.path.abspath("../src"))

from preprocessing import run_preprocessing_pipeline
from feature_engineering import run_feature_engineering_pipeline
from eda_analysis import perform_eda
from train_model import train_and_evaluate_models

print("All modules loaded successfully!")

# %% [markdown]
# ## 1. Load and Clean Raw Clickstream Data

# %%
df_clean = run_preprocessing_pipeline()
df_clean.head()

# %% [markdown]
# ## 2. Session-Level Feature Engineering
# Aggregate clickstream into 1 row per session (`composite_session_id = UserID_SessionID`).

# %%
session_df, X_train, X_test, y_train, y_test, feature_cols, scaler = run_feature_engineering_pipeline(df_clean)
print(f"Session Dataset Shape: {session_df.shape}")
session_df.head()

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
eda_metrics = perform_eda(df_clean, session_df)
for key, val in eda_metrics.items():
    print(f"{key}: {val}")

# %% [markdown]
# ## 4. Train Baseline ML Models & Evaluate Performance

# %%
summary_df, best_model, fi_df = train_and_evaluate_models(X_train, X_test, y_train, y_test)
summary_df

# %% [markdown]
# ## 5. Feature Importance Analysis

# %%
print("Top Features driving Cart Abandonment prediction:")
fi_df.head(10)
